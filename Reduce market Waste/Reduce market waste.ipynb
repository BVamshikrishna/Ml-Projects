# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv(r'C:\Users\Vamshikrishna\Desktop\Reduce market Waste\dataset\train.csv')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7007 entries, 0 to 7006
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deal_title             7007 non-null   object
#  1   Lead_name              7007 non-null   object
#  2   Industry               7006 non-null   object
#  3   Deal_value             6956 non-null   object
#  4   Weighted_amount        6482 non-null   object
#  5   Date_of_creation       7007 non-null   object
#  6   Pitch                  7007 non-null   object
#  7   Contact_no             7007 non-null   object
#  8   Lead_revenue           7007 non-null   object
#  9   Fund_category          7007 non-null   object
#  10  Geography              6035 non-null   object
#  11  Location               6996 non-null   object
#  12  POC_name               6999 non-null   object
#  13  Designation            7007 non-null   object
# ...

# %%
test_df = pd.read_csv(r'C:\Users\Vamshikrishna\Desktop\Reduce market Waste\dataset\test.csv')

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deal_title             2093 non-null   object
#  1   Lead_name              2093 non-null   object
#  2   Industry               2092 non-null   object
#  3   Deal_value             2088 non-null   object
#  4   Weighted_amount        2033 non-null   object
#  5   Date_of_creation       2093 non-null   object
#  6   Pitch                  2093 non-null   object
#  7   Contact_no             2093 non-null   object
#  8   Lead_revenue           2093 non-null   object
#  9   Fund_category          2093 non-null   object
#  10  Geography              2014 non-null   object
#  11  Location               2090 non-null   object
#  12  POC_name               2091 non-null   object
#  13  Designation            2093 non-null   object
# ...

# %%
train_df['Success_probability'].unique()
# Out:
# array([ 73.6 ,  58.9 ,  68.8 ,  64.5 ,  62.4 ,  66.3 ,  73.4 ,  74.1 ,
#         61.4 ,  66.  ,  67.9 ,  63.9 ,  71.5 ,  26.35,  60.7 ,  71.  ,
#         70.  ,  66.4 ,  61.9 ,  63.7 , 107.34,  60.1 ,  62.9 ,  68.6 ,
#         64.8 ,  68.3 ,  57.8 ,  56.2 ,  76.1 ,  60.8 ,  58.8 ,  64.1 ,
#         69.7 ,  65.6 ,  73.1 ,  69.9 ,  66.2 ,  65.8 ,  68.1 ,  70.4 ,
#         64.2 ,  -5.  ,  60.3 ,  58.6 ,  63.6 ,  68.5 ,  55.7 ,  60.2 ,
#         59.9 ,  69.4 ,  73.5 ,  59.1 ,  60.9 ,  70.6 ,  62.  ,  63.4 ,
#         66.1 ,  64.6 ,  59.6 ,  76.2 ,  62.5 ,  67.3 ,  70.8 ,  61.8 ,
#         64.  ,  65.3 ,  72.9 ,  69.2 ,  55.6 ,  67.1 ,  55.4 ,  55.9 ,
#         67.7 ,  70.1 ,  57.2 ,  69.6 ,  59.4 ,  57.5 ,  65.4 ,  61.5 ,
#         64.9 ,  63.3 ,  67.2 ,  70.7 ,  65.1 ,  61.1 ,  68.4 ,  65.7 ,
#         60.4 ,  74.8 ,  75.2 ,  61.7 ,  73.8 ,  61.6 ,  72.7 ,   8.  ,
#         57.6 ,  57.4 ,  69.3 ,  63.5 ,  64.4 ,  75.6 ,  59.  ,  56.9 ,
# ...

# %%
train_df.isnull().sum()
# Out:
# Deal_title                 0
# Lead_name                  0
# Industry                   1
# Deal_value                51
# Weighted_amount          525
# Date_of_creation           0
# Pitch                      0
# Contact_no                 0
# Lead_revenue               0
# Fund_category              0
# Geography                972
# Location                  11
# POC_name                   8
# Designation                0
# Lead_POC_email             0
# Hiring_candidate_role      0
# Lead_source                0
# Level_of_meeting           0
# Last_lead_update         633
# Internal_POC               0
# Resource                 149
# Internal_rating            0
# Success_probability        0
# dtype: int64

# %%
train_df.head()
# Out:
#    Deal_title                      Lead_name               Industry  \
# 0  TitleM5DZY  Davis, Perkins and Bishop Inc            Restaurants
# 1  TitleKIW18                 Bender PLC LLC  Construction Services
# 2  TitleFXSDN          Carter-Henry and Sons      Hospitals/Clinics
# 3  TitlePSK4Y                 Garcia Ltd Ltd            Real Estate
# 4  Title904GV               Lee and Sons PLC     Financial Services
#
#   Deal_value Weighted_amount Date_of_creation      Pitch  \
# 0    320506$      2067263.7$       2020-03-29  Product_2
# 1     39488$       240876.8$       2019-07-10  Product_2
# 2    359392$      2407926.4$       2019-07-27  Product_1
# 3     76774$       468321.4$       2021-01-30  Product_2
# 4    483896$             NaN       2019-05-22  Product_2
#
#              Contact_no             Lead_revenue Fund_category  ...  \
# 0          607.447.7883         50 - 100 Million    Category 2  ...
# 1          892-938-9493  500 Million - 1 Billion    Category 4  ...
# ...

# %%
for col in test_df.columns:
    if train_df[col].dtype == 'object':
        print(col)
# Out:
# Deal_title
# Lead_name
# Industry
# Deal_value
# Weighted_amount
# Date_of_creation
# Pitch
# Contact_no
# Lead_revenue
# Fund_category
# Geography
# Location
# POC_name
# Designation
# Lead_POC_email
# Hiring_candidate_role
# Lead_source
# Level_of_meeting
# Last_lead_update
# Internal_POC
# Resource

# %%
for col in test_df.columns:
    if train_df[col].dtype == 'object':
        if train_df[col].nunique()>20:
            train_df.drop(col,1,inplace=True)
            test_df.drop(col,1,inplace=True)
        else:
            k=0
            for val in train_df[col].value_counts().index:
                train_df[col].replace(col,k,inplace=True)
                test_df[col].replace(col,k,inplace=True)
                k+=1

# %%
train_df.head()
# Out:
#        Pitch             Lead_revenue Fund_category Geography  \
# 0  Product_2         50 - 100 Million    Category 2       USA
# 1  Product_2  500 Million - 1 Billion    Category 4     India
# 2  Product_1  500 Million - 1 Billion    Category 4       USA
# 3  Product_2  500 Million - 1 Billion    Category 3       USA
# 4  Product_2         50 - 100 Million    Category 3     India
#
#                 Designation      Lead_source Level_of_meeting  \
# 0  Executive Vice President          Website          Level 3
# 1    Chairman/CEO/President           Others          Level 1
# 2      SVP/General Counsel   Marketing Event          Level 1
# 3   CEO/Co-Founder/Chairman    Contact Email          Level 2
# 4  Executive Vice President          Website          Level 2
#
#                   Last_lead_update                      Resource  \
# 0                         No track                           NaN
# 1  Did not hear back after Level 1                            No
# ...

# %%
train_df.shape
# Out:
# (7007, 11)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
test_df['Pitch'] = le.fit_transform(test_df['Pitch'])
test_df['Lead_revenue'] = le.fit_transform(test_df['Lead_revenue'])
test_df['Fund_category'] = le.fit_transform(test_df['Fund_category'])
test_df['Designation'] = le.fit_transform(test_df['Designation'])
test_df['Lead_source'] = le.fit_transform(test_df['Lead_source'])
test_df['Level_of_meeting'] = le.fit_transform(test_df['Level_of_meeting'])

# %%
train_df['Pitch'] = le.fit_transform(train_df['Pitch'])
train_df['Lead_revenue'] = le.fit_transform(train_df['Lead_revenue'])
train_df['Fund_category'] = le.fit_transform(train_df['Fund_category'])
train_df['Designation'] = le.fit_transform(train_df['Designation'])
train_df['Lead_source'] = le.fit_transform(train_df['Lead_source'])
train_df['Level_of_meeting'] = le.fit_transform(train_df['Level_of_meeting'])

# %%
test_df.head()
# Out:
#    Pitch  Lead_revenue  Fund_category Geography  Designation  Lead_source  \
# 0      0             0              3     India            4            1
# 1      0             0              2       USA            2            1
# 2      0             0              0       USA            5            1
# 3      1             0              0     India            1            0
# 4      0             2              2       USA            2            2
#
#    Level_of_meeting                 Last_lead_update     Resource  \
# 0                 0                more than a month           No
# 1                 1                       Up-to-date          Yes
# 2                 1  Did not hear back after Level 1  Deliverable
# 3                 2                more than a month           No
# 4                 2                More than 2 weeks  Deliverable
#
#    Internal_rating
# 0             -1.0
# 1              1.0
# 2              5.0
# 3              5.0
# 4              2.0

# %%
train = train_df.drop(['Geography','Last_lead_update','Resource'],axis=1)
test = test_df.drop(['Geography','Last_lead_update','Resource'],axis=1)

# %%
train.head()
# Out:
#    Pitch  Lead_revenue  Fund_category  Designation  Lead_source  \
# 0      1             1              1            7            3
# 1      1             2              3            4            2
# 2      0             2              3            8            1
# 3      1             2              2            2            0
# 4      1             1              2            7            3
#
#    Level_of_meeting  Internal_rating  Success_probability
# 0                 2                3                 73.6
# 1                 0                5                 58.9
# 2                 0                4                 68.8
# 3                 1                1                 64.5
# 4                 1                4                 62.4

# %%
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7007 entries, 0 to 7006
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pitch                7007 non-null   int32
#  1   Lead_revenue         7007 non-null   int32
#  2   Fund_category        7007 non-null   int32
#  3   Designation          7007 non-null   int32
#  4   Lead_source          7007 non-null   int32
#  5   Level_of_meeting     7007 non-null   int32
#  6   Internal_rating      7007 non-null   int64
#  7   Success_probability  7007 non-null   float64
# dtypes: float64(1), int32(6), int64(1)
# memory usage: 273.8 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2093 entries, 0 to 2092
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Pitch             2093 non-null   int64
#  1   Lead_revenue      2093 non-null   int64
# ...

# %%
X_train = train.drop('Success_probability',1)
y_train = train['Success_probability']
X_test=test

# %%
X_train.head(10)
# Out:
#    Pitch  Lead_revenue  Fund_category  Designation  Lead_source  \
# 0      1             1              1            7            3
# 1      1             2              3            4            2
# 2      0             2              3            8            1
# 3      1             2              2            2            0
# 4      1             1              2            7            3
# 5      0             1              1            2            1
# 6      1             2              0            2            0
# 7      1             2              0            9            2
# 8      0             0              2            5            0
# 9      0             2              2            0            0
#
#    Level_of_meeting  Internal_rating
# 0                 2                3
# 1                 0                5
# 2                 0                4
# 3                 1                1
# 4                 1                4
# ...

# %%
# Out:
# 0    73.6
# 1    58.9
# 2    68.8
# 3    64.5
# 4    62.4
# Name: Success_probability, dtype: float64

# %%
from sklearn.linear_model import LinearRegression as lr

# %%
model = lr()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred)
# Out:
# [56.94706418 61.71089601 66.78815299 ... 64.38733865 64.2454441
#  64.79150591]

# %%
y_pred.shape
# Out:
# (2093,)

# %%
test_df1=pd.read_csv(r'C:\Users\Vamshikrishna\Desktop\Reduce market Waste\dataset\test.csv')

# %%
def create_submission(test,model,file_name):
    y_pred=model.predict(X_test)
    y_pred=y_pred.reshape(y_pred.shape[0])
    y_pred=y_pred.tolist()
    subs=pd.DataFrame({'Deal_title':test_df1['Deal_title'],'Success_probability':y_pred})
    subs.to_csv('file_name',index=False)

# %%
subs=pd.DataFrame({'Deal_title':test_df1['Deal_title'],'Success_probability':y_pred})
subs.to_csv('Submission.csv',index=False)

# %%
Submission_df = pd.read_csv(r'Submission.csv')
Submission_df.head()
# Out:
#    Deal_title  Success_probability
# 0  TitleAD16O            56.947064
# 1  TitleOW6CR            61.710896
# 2  TitleVVJQ5            66.788153
# 3  TitleUS8NA            68.515488
# 4  Title5VGWW            66.291393
